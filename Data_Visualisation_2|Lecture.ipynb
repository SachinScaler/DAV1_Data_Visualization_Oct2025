# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinScaler/DAV1_Data_Visualization_Oct2025/blob/main/Data_Visualisation_2%7CLecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Download data

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O vgsales.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# To: /content/vgsales.csv
# 100% 2.04M/2.04M [00:00<00:00, 12.6MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('vgsales.csv')
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16652 entries, 0 to 16651
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16652 non-null  int64
#  1   Name          16652 non-null  object
#  2   Platform      16652 non-null  object
#  3   Year          16381 non-null  float64
#  4   Genre         16652 non-null  object
#  5   Publisher     16594 non-null  object
#  6   NA_Sales      16652 non-null  float64
#  7   EU_Sales      16652 non-null  float64
#  8   JP_Sales      16652 non-null  float64
#  9   Other_Sales   16652 non-null  float64
#  10  Global_Sales  16652 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
data['Year']
# Out:
# 0        1985.0
# 1        2007.0
# 2        2012.0
# 3        2006.0
# 4        2006.0
#           ...
# 16647    2012.0
# 16648    2013.0
# 16649    2013.0
# 16650    2008.0
# 16651    2013.0
# Name: Year, Length: 16652, dtype: float64

# %%
data[data['Name'] =='Ice Hockey']
# Out:
#       Rank        Name Platform    Year   Genre   Publisher  NA_Sales  \
# 6073   639  Ice Hockey      NES  1988.0  Sports    Nintendo      0.44
# 6074  4027  Ice Hockey     2600  1980.0  Sports  Activision      0.39
# 6075  4149  Ice Hockey     2600  1991.0  Sports  Activision      0.61
# 6076  4149  Ice Hockey     2600  1992.0  Sports  Activision      0.65
# 6077  4149  Ice Hockey     SNES  1993.0  Sports  Activision      0.68
# 6078  4149  Ice Hockey     SNES  1994.0  Sports  Activision      0.75
# 6079  4149  Ice Hockey     SNES  1995.0  Sports  Activision      0.78
# 6080  4149  Ice Hockey     SNES  1996.0  Sports  Activision      0.76
# 6081  4149  Ice Hockey     SNES  1997.0  Sports  Activision      0.82
# 6082  4149  Ice Hockey     SNES  1998.0  Sports  Activision      0.88
# 6083  4149  Ice Hockey     SNES  1999.0  Sports  Activision      0.85
# 6084  4148  Ice Hockey     SNES  2000.0  Sports  Activision      0.84
# ...

# %%
len(data[data['Name'] =='Ice Hockey'].Year)
# Out:
# 41

# %%
# try bar plot

# %%
data_ih = data[data['Name'] =='Ice Hockey']
data_ih
# Out:
#       Rank        Name Platform    Year   Genre   Publisher  NA_Sales  \
# 6073   639  Ice Hockey      NES  1988.0  Sports    Nintendo      0.44
# 6074  4027  Ice Hockey     2600  1980.0  Sports  Activision      0.39
# 6075  4149  Ice Hockey     2600  1991.0  Sports  Activision      0.61
# 6076  4149  Ice Hockey     2600  1992.0  Sports  Activision      0.65
# 6077  4149  Ice Hockey     SNES  1993.0  Sports  Activision      0.68
# 6078  4149  Ice Hockey     SNES  1994.0  Sports  Activision      0.75
# 6079  4149  Ice Hockey     SNES  1995.0  Sports  Activision      0.78
# 6080  4149  Ice Hockey     SNES  1996.0  Sports  Activision      0.76
# 6081  4149  Ice Hockey     SNES  1997.0  Sports  Activision      0.82
# 6082  4149  Ice Hockey     SNES  1998.0  Sports  Activision      0.88
# 6083  4149  Ice Hockey     SNES  1999.0  Sports  Activision      0.85
# 6084  4148  Ice Hockey     SNES  2000.0  Sports  Activision      0.84
# ...

# %% [markdown]
# Lineplot

# %%
sns.lineplot(x='Year', y='NA_Sales', data=data_ih)
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
sns.lineplot(x='Year', y='Global_Sales', data=data_ih)
# Out:
# <Axes: xlabel='Year', ylabel='Global_Sales'>

# %%
data_b = data[data['Name'] =='Baseball']
data_b
# Out:
#      Rank      Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 941   324  Baseball      NES  1980.0  Sports  Nintendo  0.459000  2.320000
# 942   422  Baseball      NES  1983.0  Sports  Nintendo  0.468529  2.697415
# 943   231  Baseball       GB  1985.0  Sports  Nintendo  0.473000  3.074830
# 944  1144  Baseball       GB  1989.0  Sports  Nintendo  0.478448  3.452245
# 945   134  Baseball       GB  1992.0  Sports  Nintendo  0.520000  3.829660
# 946   134  Baseball       GB  1995.0  Sports  Nintendo  0.680000  3.829660
# 947   134  Baseball       PS  1997.0  Sports  Nintendo  0.720000  4.207075
# 948  2321  Baseball      Wii  2003.0  Sports  Nintendo  0.730000  4.584489
# 949   134  Baseball       GB  2004.0  Sports  Nintendo  0.800000  3.829660
# 950  1311  Baseball      Wii  2005.0  Sports  Nintendo  0.710000  4.961904
# 951   134  Baseball     X361  2007.0  Sports  Nintendo  0.530000  3.829660
# ...

# %%
sns.lineplot(x='Year', y='NA_Sales', data=data_b)
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
plt.title('Ice Hockey Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_ih)
plt.show()

# %%
plt.title('Ice Hockey Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_ih, color ='red')
plt.show()

# %%
plt.title('Ice Hockey Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.xlim(left=1995, right=2005)
sns.lineplot(x='Year', y='NA_Sales', data=data_ih, color ='red')
plt.show()

# %%
plt.title('Ice Hockey Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_ih)
plt.show()

# %%
plt.title('Baseball Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_b)
plt.show()

# %%
# lets plot both of them side by side: subplots, we will see after break

# %%
### subplot of ice hockey and baseball
plt.subplots(1,2)
# Out:
# (<Figure size 640x480 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
plt.subplots(2,1)
# Out:
# (<Figure size 640x480 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
plt.subplot(1, 2, 1) # 1 row 2 column, get the first spot

plt.title('Ice Hockey Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_ih)

plt.subplot(1, 2, 2)
plt.title('Baseball Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_b)
plt.show()

# %%
plt.figure(figsize =(10, 6))

plt.title('Ice Hockey vs Baseball Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_ih, label='Ice Hockey')


sns.lineplot(x='Year', y='NA_Sales', data=data_b, label='Baseball')

plt.legend()
plt.show()

# %%
## Plotly
import plotly.express as px

px.line(data_ih, x='Year', y='NA_Sales', title='Ice Hockey Sales Trend')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize =(10, 6))

plt.title('Ice Hockey vs Baseball Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_ih, label='Ice Hockey')


sns.lineplot(x='Year', y='NA_Sales', data=data_b, label='Baseball')

plt.legend(loc='lower right')
plt.show()

# %%
plt.figure(figsize =(10, 6))

plt.title('Ice Hockey vs Baseball Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_ih, label='Ice Hockey')


sns.lineplot(x='Year', y='NA_Sales', data=data_b, label='Baseball')

plt.legend(loc=(0.5, 0.5))
plt.show()

# %%
plt.figure(figsize =(10, 6))

plt.title('Ice Hockey vs Baseball Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_ih, label='Ice Hockey')


sns.lineplot(x='Year', y='NA_Sales', data=data_b, label='Baseball')

plt.legend(loc=(0.5, 0.5),  ncol=2)
plt.show()

# %%
print(max(data_ih['NA_Sales']))
# Out:
# 0.9

# %%
print(data_ih[data_ih['NA_Sales']==0.9])
# Out:
#       Rank        Name Platform    Year   Genre   Publisher  NA_Sales  \
# 6086  3012  Ice Hockey     SNES  2002.0  Sports  Activision       0.9
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 6086      0.02       0.0         0.01          0.47

# %%
plt.figure(figsize =(10, 6))

plt.title('Ice Hockey Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_ih, label='Ice Hockey')
plt.text(2002, max(data_ih['NA_Sales']), "Sales peaked here")
plt.show()

# %%
plt.figure(figsize =(10, 6))

plt.title('Ice Hockey Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y='NA_Sales', data=data_ih, label='Ice Hockey')
plt.text(2002, max(data_ih['NA_Sales']), "Sales peaked here")
plt.grid()
plt.show()

# %% [markdown]
# ### Additional HW:
# 1) Highlight the maximum point using arrow or star
# 2) Customize the grid: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html

# %%
data[['Rank', 'NA_Sales']]
# Out:
#         Rank  NA_Sales
# 0       2061  4.569217
# 1       9137  2.076955
# 2      14279  1.145709
# 3       8359  2.031986
# 4       7109  2.792725
# ...      ...       ...
# 16647   7925  4.409308
# 16648   6279  3.033887
# 16649   6977  3.228043
# 16650  15422  1.087977
# 16651  12919  1.081046
#
# [16652 rows x 2 columns]

# %%
plt.figure(figsize =(10, 6))

sns.lineplot(x='Rank', y='NA_Sales', data=data)

plt.show()

# %%
data[data['Rank']==6]
# Out:
#        Rank    Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 13923     6  Tetris       GB  1989.0  Puzzle  Nintendo  8.144152  5.815365
#
#        JP_Sales  Other_Sales  Global_Sales
# 13923  6.439835     4.455273     24.854625

# %%
plt.figure(figsize =(10, 6))

sns.lineplot(x='Rank', y='NA_Sales', data=data)
plt.xlim(left=1, right=10)
plt.show()

plt.show()

# %%
plt.figure(figsize =(10, 6))

sns.scatterplot(x='Rank', y='NA_Sales', data=data)

plt.show()

# %% [markdown]
# ### Linear Regresion
# ### Regressionplot with seaborn

# %% [markdown]
# ## Bonus Content:

# %%
plt.figure(figsize =(10, 6))

sns.regplot(x='Rank', y='NA_Sales', data=data, line_kws={'color':'red'})

plt.show()

# %% [markdown]
# Get the Genres, Publisher and Platform categorical values from data.
#
# - Since we have a lot of categories of each of them, Extract top 3 most common of each of the above columns to our analysis easier.
# - Plot Countplots of Publisher, Platform respectively

# %%
data = pd.read_csv('vgsales.csv')
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
top3_pub = data['Publisher'].value_counts()[:3]

top3_pub
# Out:
# Publisher
# Electronic Arts       1351
# Activision            1014
# Namco Bandai Games     932
# Name: count, dtype: int64

# %%
top3_pub = data['Publisher'].value_counts().index[:3]
top3_gen = data['Genre'].value_counts().index[:3]
top3_plat = data['Platform'].value_counts().index[:3]

# %%
top3_data = data.loc[(data["Publisher"].isin(top3_pub)) & (data["Platform"].isin(top3_plat)) & (data['Genre'].isin(top3_gen))]
top3_data.head()
# Out:
#      Rank                               Name Platform    Year   Genre  \
# 2   14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0  Action
# 13   2742                      [Prototype 2]      PS3  2012.0  Action
# 16   1604                        [Prototype]      PS3  2009.0  Action
# 19   1741             007: Quantum of Solace      PS3  2008.0  Action
# 21   4501             007: Quantum of Solace      PS2  2008.0  Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2   Namco Bandai Games  1.145709  1.762339  1.493442     0.408693
# 13          Activision  3.978349  3.727034  0.848807     2.792725
# 16          Activision  4.569217  4.108402  1.187272     3.339269
# 19          Activision  4.156030  4.346074  1.087977     3.390562
# 21          Activision  3.228043  2.738800  2.585598     3.652926
#
#     Global_Sales
# 2       4.982552
# 13     11.447989
# 16     13.181205
# 19     12.980643
# 21     11.780257

# %%
plt.figure(figsize =(10, 8))
sns.countplot(x='Publisher', data=top3_data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize =(10, 8))
sns.countplot(x='Publisher', hue='Genre' , data=top3_data)
plt.show()

# %%
df_stacked_data = pd.crosstab(index=top3_data['Publisher'], columns=top3_data['Genre'])
df_stacked_data
# Out:
# Genre               Action  Misc  Sports
# Publisher
# Activision             102    47      45
# Electronic Arts         59    18     186
# Namco Bandai Games     100    48      12

# %%
plt.figure(figsize =(10, 8))

df_stacked_data.plot(kind='bar', stacked=True)
plt.show()

# %%
top3_data['Global_Sales']
# Out:
# 2         4.982552
# 13       11.447989
# 16       13.181205
# 19       12.980643
# 21       11.780257
#            ...
# 16438     3.509168
# 16479     7.359902
# 16601     7.372592
# 16636     6.915540
# 16640     5.969572
# Name: Global_Sales, Length: 617, dtype: float64

# %%
plt.figure(figsize =(10, 6))

sns.scatterplot(x='Global_Sales', y='Global_Sales', data=data)

plt.show()

# %%
plt.figure(figsize =(10, 6))

sns.boxplot(y='Global_Sales', data=top3_data)

plt.show()

# %%
plt.figure(figsize =(10, 6))

sns.boxplot(y='Global_Sales', hue='Publisher', data=top3_data)

plt.show()

# %%
plt.figure(figsize =(10, 6))

sns.boxplot(y='Global_Sales', x='Publisher', data=top3_data)

plt.show()

# %%
plt.figure(figsize =(10, 6))

sns.boxplot(y='JP_Sales', x='Publisher', data=top3_data)

plt.show()

# %%
plt.figure(figsize =(10, 6))

sns.barplot(y='JP_Sales', x='Publisher', data=top3_data, estimator=lambda x: len(x)) # estimator takes a function

plt.show()

# %% [markdown]
# ### Additional: can you add custizations such as title xlabel, ylabel, color etc in both of the below method

# %%
plt.subplot(2, 2, 1)
plt.scatter(top3_data['NA_Sales'], top3_data['EU_Sales'])

plt.subplot(2, 2, 2)
plt.scatter(top3_data['NA_Sales'], top3_data['JP_Sales'])


plt.subplot(2, 2, 3)
plt.scatter(top3_data['NA_Sales'], top3_data['Other_Sales'])

plt.subplot(2, 2, 4)
plt.scatter(top3_data['NA_Sales'], top3_data['Global_Sales'])

# %%
fig, ax = plt.subplots(2, 2)
ax[0,0].scatter(top3_data['NA_Sales'], top3_data['EU_Sales'])

ax[0,1].scatter(top3_data['NA_Sales'], top3_data['JP_Sales'])

ax[1,0].scatter(top3_data['NA_Sales'], top3_data['Other_Sales'])

ax[1,1].scatter(top3_data['NA_Sales'], top3_data['Global_Sales'])

# %%
plt.figure(figsize=(20,12)).suptitle("Video Games Sales Dashboard",fontsize=20)

# using a 2x3 subplot
plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)
plt.title('NA vs EU Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('EU', fontsize=12)

plt.subplot(2, 3, 3)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='red')
plt.title('NA vs JP Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('JP', fontsize=12)

# Countplot of publishers
plt.subplot(1,3,2)
sns.countplot(x='Publisher', data=top3_data)
plt.title('Count of games by each Publisher', fontsize=12)
plt.xlabel('Publisher', fontsize=12)
plt.ylabel('Count of games', fontsize=12)

plt.subplot(2, 3, 4)
sns.scatterplot(x='NA_Sales', y='Other_Sales', data=top3_data, color='green')
plt.title('NA vs Other Region Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Other', fontsize=12)

plt.subplot(2, 3, 6)
sns.scatterplot(x='NA_Sales', y='Global_Sales', data=top3_data, color='orange')
plt.title('NA vs Global Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Global', fontsize=12)

plt.show()

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
# feature Engineering
data['Total_Sales'] = data['NA_Sales'] + data['EU_Sales'] + data['JP_Sales'] + data['Other_Sales']

# %%
data['Total_Sales']
# Out:
# 0        13.034128
# 1         6.999114
# 2         4.810183
# 3         7.044715
# 4         8.318705
#            ...
# 16647    12.833178
# 16648     8.916906
# 16649     8.153439
# 16650     3.163228
# 16651     5.194807
# Name: Total_Sales, Length: 16652, dtype: float64
