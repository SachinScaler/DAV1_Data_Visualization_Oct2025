# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinScaler/DAV1_Data_Visualization_Oct2025/blob/main/Data_Visualisation_3%7CLecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

git_path = 'https://raw.githubusercontent.com/SachinScaler/DAV1_Data_Visualization_Oct2025/refs/heads/main/vgsales.csv'
data = pd.read_csv(git_path)
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
top3_pub = data['Publisher'].value_counts().index[:3]
top3_gen = data['Genre'].value_counts().index[:3]
top3_plat = data['Platform'].value_counts().index[:3]
top3_data = data.loc[(data["Publisher"].isin(top3_pub)) & (data["Platform"].isin(top3_plat)) & (data['Genre'].isin(top3_gen))]
top3_data
# Out:
#         Rank                                               Name Platform  \
# 2      14279                  .hack: Sekai no Mukou ni + Versus      PS3
# 13      2742                                      [Prototype 2]      PS3
# 16      1604                                        [Prototype]      PS3
# 19      1741                             007: Quantum of Solace      PS3
# 21      4501                             007: Quantum of Solace      PS2
# ...      ...                                                ...      ...
# 16438  14938  Yes! Precure 5 Go Go Zenin Shu Go! Dream Festival       DS
# 16479  10979                              Young Justice: Legacy      PS3
# 16601  11802                         ZhuZhu Pets: Quest for Zhu       DS
# 16636   9196                           Zoobles! Spring to Life!       DS
# 16640   9816                                               Zubo       DS
#
#          Year   Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
plt.figure(figsize=(20,12)).suptitle("Video Games Sales Dashboard",fontsize=20)

# using a 2x3 subplot
plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)
plt.title('NA vs EU Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('EU', fontsize=12)

plt.subplot(2, 3, 3)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='red')
plt.title('NA vs JP Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('JP', fontsize=12)

# Countplot of publishers
plt.subplot(1,3,2)
sns.countplot(x='Publisher', data=top3_data)
plt.title('Count of games by each Publisher', fontsize=12)
plt.xlabel('Publisher', fontsize=12)
plt.ylabel('Count of games', fontsize=12)

plt.subplot(2, 3, 4)
sns.scatterplot(x='NA_Sales', y='Other_Sales', data=top3_data, color='green')
plt.title('NA vs Other Region Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Other', fontsize=12)

plt.subplot(2, 3, 6)
sns.scatterplot(x='NA_Sales', y='Global_Sales', data=top3_data, color='orange')
plt.title('NA vs Global Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Global', fontsize=12)

plt.show()

# %%
plt.figure(figsize=(20,12)).suptitle("Video Games Sales Dashboard",fontsize=20)

# using a 2x3 subplot
plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)
plt.title('NA vs EU Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('EU', fontsize=12)

plt.subplot(2, 3, 3)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='red')
plt.title('NA vs JP Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('JP', fontsize=12)

# Countplot of publishers
plt.subplot(2,3,(2, 5))
sns.countplot(x='Publisher', data=top3_data)
plt.title('Count of games by each Publisher', fontsize=12)
plt.xlabel('Publisher', fontsize=12)
plt.ylabel('Count of games', fontsize=12)

plt.subplot(2, 3, 4)
sns.scatterplot(x='NA_Sales', y='Other_Sales', data=top3_data, color='green')
plt.title('NA vs Other Region Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Other', fontsize=12)

plt.subplot(2, 3, 6)
sns.scatterplot(x='NA_Sales', y='Global_Sales', data=top3_data, color='orange')
plt.title('NA vs Global Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Global', fontsize=12)

plt.show()

# %% [markdown]
# ### NNC:

# %%
top3_data.head()
# Out:
#      Rank                               Name Platform    Year   Genre  \
# 2   14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0  Action
# 13   2742                      [Prototype 2]      PS3  2012.0  Action
# 16   1604                        [Prototype]      PS3  2009.0  Action
# 19   1741             007: Quantum of Solace      PS3  2008.0  Action
# 21   4501             007: Quantum of Solace      PS2  2008.0  Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2   Namco Bandai Games  1.145709  1.762339  1.493442     0.408693
# 13          Activision  3.978349  3.727034  0.848807     2.792725
# 16          Activision  4.569217  4.108402  1.187272     3.339269
# 19          Activision  4.156030  4.346074  1.087977     3.390562
# 21          Activision  3.228043  2.738800  2.585598     3.652926
#
#     Global_Sales
# 2       4.982552
# 13     11.447989
# 16     13.181205
# 19     12.980643
# 21     11.780257

# %%
plt.figure(figsize = (8, 8))

sns.scatterplot(x='NA_Sales', y='EU_Sales', hue='Genre' , data = top3_data)

plt.xlabel('NA Sales', fontsize = 12)
plt.ylabel('EU Sales', fontsize = 12)


plt.show()

# %% [markdown]
# - Can you customize type of .

# %%
plt.figure(figsize = (8, 8))

sns.regplot(x='NA_Sales', y='EU_Sales', data = top3_data)

plt.xlabel('NA Sales', fontsize = 12)
plt.ylabel('EU Sales', fontsize = 12)


plt.show()

# %%
plt.figure(figsize=(12,8))

sns.boxplot(x='Publisher', y='Global_Sales', hue = 'Genre', data=top3_data)

plt.xlabel('Publisher', fontsize=12)
plt.ylabel('Global Sales', fontsize=12)
plt.show()

# %% [markdown]
# HW:
# 1) Can you write a few insights using above chart
# 2) Can you calculate avg sales for each publisher in each genre and plot using appropriate chart

# %%
plt.figure(figsize = (8, 8))

sns.scatterplot(x='NA_Sales', y='EU_Sales', hue='Rank' , data = top3_data)

plt.xlabel('NA Sales', fontsize = 12)
plt.ylabel('EU Sales', fontsize = 12)


plt.show()

# %%
plt.figure(figsize = (10, 8))

sns.scatterplot(x='NA_Sales', y='EU_Sales', size='Rank', sizes=(1, 500), data = top3_data)

plt.xlabel('NA Sales', fontsize = 12)
plt.ylabel('EU Sales', fontsize = 12)


plt.show()

# %%
plt.figure(figsize = (10, 8))

sns.scatterplot(x='NA_Sales', y='EU_Sales', hue ='Genre', size='Rank', sizes=(1, 500), data = top3_data)

plt.xlabel('NA Sales', fontsize = 12)
plt.ylabel('EU Sales', fontsize = 12)


plt.show()

# %%
plt.figure(figsize = (10, 8))

sns.jointplot(x ='NA_Sales', kind='reg', y='EU_Sales', data=top3_data)

plt.show()

# %%
plt.figure(figsize = (10, 8))

sns.jointplot(x ='NA_Sales', kind='kde', y='EU_Sales', data=top3_data)

plt.show()

# %%
plt.figure(figsize = (10, 8))

sns.jointplot(x ='NA_Sales', hue = 'Genre', y='EU_Sales', data=top3_data)

plt.show()

# %%
top3_data.head()
# Out:
#      Rank                               Name Platform    Year   Genre  \
# 2   14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0  Action
# 13   2742                      [Prototype 2]      PS3  2012.0  Action
# 16   1604                        [Prototype]      PS3  2009.0  Action
# 19   1741             007: Quantum of Solace      PS3  2008.0  Action
# 21   4501             007: Quantum of Solace      PS2  2008.0  Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2   Namco Bandai Games  1.145709  1.762339  1.493442     0.408693
# 13          Activision  3.978349  3.727034  0.848807     2.792725
# 16          Activision  4.569217  4.108402  1.187272     3.339269
# 19          Activision  4.156030  4.346074  1.087977     3.390562
# 21          Activision  3.228043  2.738800  2.585598     3.652926
#
#     Global_Sales
# 2       4.982552
# 13     11.447989
# 16     13.181205
# 19     12.980643
# 21     11.780257

# %%
plt.figure(figsize = (10, 8))

sns.jointplot(x ='NA_Sales', y='NA_Sales', data=top3_data)

plt.show()

# %%
plt.figure()

sns.pairplot(data=top3_data)

plt.show()

# %%
sns.regplot(x='Global_Sales', y='Year', data=top3_data)
plt.show()

# %%
###

# %%
top3_data.head()
# Out:
#      Rank                               Name Platform    Year   Genre  \
# 2   14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0  Action
# 13   2742                      [Prototype 2]      PS3  2012.0  Action
# 16   1604                        [Prototype]      PS3  2009.0  Action
# 19   1741             007: Quantum of Solace      PS3  2008.0  Action
# 21   4501             007: Quantum of Solace      PS2  2008.0  Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2   Namco Bandai Games  1.145709  1.762339  1.493442     0.408693
# 13          Activision  3.978349  3.727034  0.848807     2.792725
# 16          Activision  4.569217  4.108402  1.187272     3.339269
# 19          Activision  4.156030  4.346074  1.087977     3.390562
# 21          Activision  3.228043  2.738800  2.585598     3.652926
#
#     Global_Sales
# 2       4.982552
# 13     11.447989
# 16     13.181205
# 19     12.980643
# 21     11.780257

# %%
num = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']

num_data = top3_data[num]
num_data.head()
# Out:
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 2   1.145709  1.762339  1.493442     0.408693      4.982552
# 13  3.978349  3.727034  0.848807     2.792725     11.447989
# 16  4.569217  4.108402  1.187272     3.339269     13.181205
# 19  4.156030  4.346074  1.087977     3.390562     12.980643
# 21  3.228043  2.738800  2.585598     3.652926     11.780257

# %%
num_data.corr() # statistical calculation to calculate pearson correlation
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# NA_Sales      1.000000  0.617483 -0.233315     0.794353      0.856300
# EU_Sales      0.617483  1.000000 -0.208249     0.771105      0.864147
# JP_Sales     -0.233315 -0.208249  1.000000    -0.355825     -0.014193
# Other_Sales   0.794353  0.771105 -0.355825     1.000000      0.878816
# Global_Sales  0.856300  0.864147 -0.014193     0.878816      1.000000

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(num_data.corr(), annot=False, cmap='coolwarm')
# Out:
# <Axes: >

# %%
help(sns.heatmap)
# Out:
# Help on function heatmap in module seaborn.matrix:
#
# heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)
#     Plot rectangular data as a color-encoded matrix.
#
#     This is an Axes-level function and will draw the heatmap into the
#     currently-active Axes if none is provided to the ``ax`` argument.  Part of
#     this Axes space will be taken and used to plot a colormap, unless ``cbar``
#     is False or a separate Axes is provided to ``cbar_ax``.
#
#     Parameters
#     ----------
#     data : rectangular dataset
#         2D dataset that can be coerced into an ndarray. If a Pandas DataFrame
#         is provided, the index/column information will be used to label the
#         columns and rows.
#     vmin, vmax : floats, optional
# ...

# %%
# Example DataFrame
data = {
    'Country': ['USA', 'China', 'Japan', 'Germany'],
    'Gold': [30, 35, 20, 25],
    'Silver': [20, 25, 15, 18],
    'Bronze': [15, 20, 10, 12]
}

df = pd.DataFrame(data)
df
# Out:
#    Country  Gold  Silver  Bronze
# 0      USA    30      20      15
# 1    China    35      25      20
# 2    Japan    20      15      10
# 3  Germany    25      18      12

# %%
df_melted = df.melt(id_vars='Country', var_name='Medal', value_name='Count')
df_melted.head()
# Out:
#    Country   Medal  Count
# 0      USA    Gold     30
# 1    China    Gold     35
# 2    Japan    Gold     20
# 3  Germany    Gold     25
# 4      USA  Silver     20

# %%
sns.barplot(x='Country', y='Count', hue='Medal', data=df_melted)
# Out:
# <Axes: xlabel='Country', ylabel='Count'>

# %% [markdown]
# We are analyzing the results of the Olympics, and want to find the count of gold, silver, and bronze medals won by each country.

# %%
plt.figure(figsize=(12, 6))

# Subplot spanning the entire first row (1st to 3rd index)
plt.subplot(2, 3, (1, 3))
plt.title('This subplot spans the first row')
plt.plot([1, 2, 3], [4, 5, 6], marker='o')

# Create individual subplots for the remaining cells
plt.subplot(2, 3, 4)
plt.title('2nd Row, 1st Column')
plt.plot([1, 2], [4, 5], marker='x')

plt.subplot(2, 3, 5)
plt.title('2nd Row, 2nd Column')
plt.plot([1, 2], [2, 4], marker='s')

plt.subplot(2, 3, 6)
plt.title('2nd Row, 3rd Column')
plt.plot([1, 2], [3, 6], marker='d')

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()
